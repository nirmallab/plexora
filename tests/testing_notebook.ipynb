# %%
from plexora.jupyter import PlexoraViewer

# %%
import sys, os
print("executable:", sys.executable)
print("cwd:", os.getcwd())

# %%
PlexoraViewer(datasource="orion_mac")

# %%
import anndata as ad

# %%
adata = ad.read_h5ad('/Users/aj/Partners HealthCare Dropbox/Ajit Nirmal/nirmal lab/resources/exemplarData/orion/orion.h5ad')
# Out:
# /var/folders/k5/3pb7tmfn0551jy0cf67ljdf00000gq/T/ipykernel_90762/273359029.py:1: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   adata = ad.read_h5ad('/Users/aj/Partners HealthCare Dropbox/Ajit Nirmal/nirmal lab/resources/exemplarData/orion/orion.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 13061 × 18
#     obs: 'X_centroid', 'Y_centroid', 'Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity', 'Solidity', 'Extent', 'Orientation', 'CellID', 'imageid', 'phenotype', 'id', 'leiden', 'simplified_leiden'
#     uns: 'all_markers', 'gates'
#     layers: 'log', None (.X)

# %%
adata.var_names
# Out:
# Index(['AFF1', 'PECAM1', 'PTPRC', 'CD68', 'ARG1', 'CD4', 'FOXP3', 'CD8A',
#        'PTPRC', 'MS4A1', 'CD274', 'CD3E', 'CD163', 'CDH1', 'PDCD1', 'MKI67',
#        'KRT17', 'ACTA2'],
#       dtype='str')

# %%
adata.uns['all_markers']
# Out:
# array(['DNA', 'AF1', 'CD31', 'CD45', 'CD68', 'Argo550', 'CD4', 'FOXP3',
#        'CD8a', 'CD45RO', 'CD20', 'PDL1', 'CD3e', 'CD163', 'ECAD', 'PD1',
#        'Ki67', 'PanCK', 'SMA'], dtype=object)

# %%
adata.layers['log'].max()
# Out:
# np.float64(2.2910363945427608)

# %%
adata.uns['gates']
# Out:
#            image--unmicst_cellRing
# var_names
# AFF1                      1.912542
# PECAM1                         NaN
# PTPRC                     2.005000
# CD68                           NaN
# ARG1                           NaN
# CD4                            NaN
# FOXP3                          NaN
# CD8A                           NaN
# PTPRC                          NaN
# MS4A1                          NaN
# CD274                          NaN
# CD3E                           NaN
# CD163                     2.001000
# CDH1                           NaN
# PDCD1                          NaN
# MKI67                     1.995000
# KRT17                     2.001000
# ACTA2                          NaN
